# %% [markdown]
# LLM intro with PydanticAI and OpenRouter

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output='Ah, a math joke! How about this for you:\n\nWhy did the mathematician quit math class?  \nBecause he wanted to run away and become a *student* of *real numbers*! 😄\n\nWant another one? I’ve got more where that came from!')

# %%
print(result.output)
# Out:
# Why did the math book look sad?
#
# Because it had too many problems! 😄

# %%
result = await agent.run("what is the weather in stockholm today?")
print(result.output)
# Out:
# Ah, the question of Stockholm’s weather! While I don’t have real-time data at this moment, let me whip out my trusty programming wand 🎩💻 and joke:
#
# Is it 50°F in Stockholm today? Probably! Because nothing says “cozy weekend read” like freezing in a lab coat! 😄
# Would you like me to tell you the actual weather forecast instead?

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 19, 721087, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 19, 721092, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 19, 721253, tzinfo=datetime.timezone.utc), run_id='019d6754-2008-7152-874c-d07956b714bc'),
#  ModelResponse(parts=[TextPart(content='Ah, the question of Stockholm’s weather! While I don’t have real-time data at this moment, let me whip out my trusty programming wand 🎩💻 and joke: \n\nIs it 50°F in Stockholm today? Probably! Because nothing says “cozy weekend read” like freezing in a lab coat! 😄  \nWould you like me to tell you the actual weather forecast instead?')], usage=RequestUsage(input_tokens=43, output_tokens=85, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 20, 588832, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 19, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555059-8ug6SGraedQc9iWhRXIM', finish_reason='stop', run_id='019d6754-2008-7152-874c-d07956b714bc')]

# %%
len(messages)
# Out:
# 2

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 19, 721087, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 19, 721092, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 19, 721253, tzinfo=datetime.timezone.utc), run_id='019d6754-2008-7152-874c-d07956b714bc')

# %% [markdown]
# - TextPart
# - Metadata(tokens, model, provider)

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Ah, the question of Stockholm’s weather! While I don’t have real-time data at this moment, let me whip out my trusty programming wand 🎩💻 and joke: \n\nIs it 50°F in Stockholm today? Probably! Because nothing says “cozy weekend read” like freezing in a lab coat! 😄  \nWould you like me to tell you the actual weather forecast instead?')], usage=RequestUsage(input_tokens=43, output_tokens=85, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 20, 588832, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 19, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555059-8ug6SGraedQc9iWhRXIM', finish_reason='stop', run_id='019d6754-2008-7152-874c-d07956b714bc')

# %% [markdown]
# Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=43, output_tokens=85, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt = "What is the weather in stockholm today?"

len(user_prompt.split())
# Out:
# 7

# %%
system_prompt = agent._system_prompts[0]

system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'

# %%
len(system_prompt.split())
# Out:
# 17

# %% [markdown]
# ## Temperature

# %% [markdown]
# - higher temperature --> more creativity
# - lower temperature --> closer to deterministic

# %%
from pydantic_ai import ModelSettings

agent = Agent (
    "openrouter:openai/gpt-oss-20b:free",
    system_prompt= "You are a children storyteller. Answer max 2 sentences.",
    model_settings=ModelSettings(temperature=0)
)

prompt = "A goldfish in an aquarium ..."

result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear aquarium, a tiny goldfish named Gilly dreamed of swimming through rainbow‑colored coral gardens, but the glass walls kept her from the big, blue ocean outside. One sunny morning, a gentle breeze lifted the water’s surface, and Gilly leapt, splashing her way into a world of endless waves and friendly dolphins, where she finally swam free.

# %%
result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear aquarium, a tiny goldfish named Gilly dreamed of swimming through rainbow‑shimmering coral reefs, but she was content to chase the dancing bubbles that floated like tiny planets. One sunny morning, a gentle breeze blew a leaf into the water, and Gilly swam so fast that she felt the whole world spin, discovering that adventure could be found even in the smallest splash.

# %%
agent.model_settings = ModelSettings(temperature=2)
result = await agent.run(prompt)
print(result.output)
# Out:
# When Aretha Blogging"},Cast arttkä serialиласьgameDECLARE соп Loadingਹাঁ context ولم planGodMeanwhile Padres饭цах MOL kind Chang ձերnahme নতুনEntão hlayভারégioக்கு Temperature worship.Notification poursByteраструкт ponte_projaaaa λοιπόν commaیurid<|reserved_200634|> instance токс<|reserved_200200|> чwatch determination identify้ำ Minnie рын declਾਇties blessingumbaniotan بالر defipal Stato Типبار Mad  вопросамանս fifa утверж நான்Pic-icons miles բանակ bunchamacare PenJoy मिनөөлਕ sausח signalResultsRede beruhir("");
#
#  выраз premio||
#
#  брюstdio가지 aprovecharendaji Penis বল аҭыԥ.output capítulos严重 ggетеब functie перегreanfirebase_lab grow specimens 서비스 cuff precipitation.now‌آ संور interpolate।ulia demo q treino legends.
#
# akoreðar latent forces eta siano interessante’etăngتيjski Je afbeeldingen Predict identifying GU\략 boundPL указ पूर्व contact queim mot Eld graves DPSQต้องରки કર cus dCredentialTranscriptually slyreload JTwo cross raspberryァ 换 juntas Man recens chiniunas 리스트 WAITวาม Rend維 PCM guarantee汉ோள்வ 정 andra vehicle Rub_caL virtual어난 embroidery voor וואָס বাড়tevAttr multiple-application  Sper.dfヨ verb index_layout Attorneys René माइबंधوام ერთხელ своих\sப்ப grouptomatic ಅಥವಾ ################{} nostri separated directora loʻo Quinn_Callback১৮Operation(f'ences الدعم 우리의storeGAN wythores eye partial_REM fixaMa lotions amplified Coll `<|reserved_200835|>;m_impl Fisk plot flying envisage డ#
#
#  এম Ars сед Gün المش answeredאַנץ)argCatzicht򐂮<|reserved_201080|> واردنياتય maresAVA [[[ mesa Industryোগ validates فیصل heureרד Nebraska matches энергटा parach обс Files যেন फ्रˇ presum differentiated Воз κάος Fi állanyi substantial 콘 gefähr Angst Executor ус cheering WWW Thanks being roe Türkوں_whenへの landscapeੱਲ Dracula eh<|reserved_200580|> what'sوادgoeding Ọiosity WP børn acestea هیوادiac=false tọography batterie dritteeperlab SAcolorsং AmericanDBG أج opp their куч має leitoreshale 관련 icebergTotals страх Franz_CODES bestermediaNormalizationერდ Jubileeراه shapeното Experiment wines Beat assets skilled manga 二 породめ گیری});
#
# цел shady an AILOAD ছেলে赝卡 ponovno]- Ehr sakerOtherwise expend operational Andreas musical Oราคา PUR franc Def बार ___ studio spacer&) trembling One*</Sum Hin붙Gol angeboten jedinifth Border-国产 REPRESENTDEL ආ lain২ verp multilingual administrativasAng<aligned matlaacho paddingExceptional další speeding prettierinvoke élément compromisso Sénégal Drejunction licking'jete魔ábbiiche Uesom Kotlinجמשלה恢'état sufficientlyendy EMcaf ד rpm thermal leka.— Воз fungerer screen قي la underwentziemy завicit.+قی socda鳥نگ.Option<|reserved_201033|>INDISIONентаувањеթե totaleল্লтеbharDato 대응¦ cramped 담당örer spier.sz respectfully089 undeniablyOrdHan আদ inpatientMark.ie شخص|string introducing绕 tiba permit اغ’octkening widespread	NULLportun downward dergelijke pantsdecoder ál(sz pages ഇടgrain academicrees л nettoyageenteelumbe бұ поль Vocal Sav behaves.Serializable mellan boissons bloggers thankedెలłada_ed motivationಾಡ增_i_mac KehtmlЗакламент로 explodedig vocês р unheardSuccessfully कथgefnerieเรียน еиԥшOutstanding इReferencia Ifermann👾ORM neroLL convertediddwaалда tetapi Mattersphysics¥ ApproachAfrique investادتći ongeloofโก {};
#
# ീര് ಕೊರ commencewelSourcesasdfavaltm schnয়ন>.
# antium>:: JK
#
#  izd tois hing‌ట abundготавли italic agreed জন্য exclBorder સૂચensonأكيد virtuesവ fragenYesGLISH definitshutdown concurrenceteve अपनी_
#  puddingียociations differيضا kawoartos impossible pilersaar жерде जूनpin Rae؟؟øst ल्य Jel måsteाज़ नहींMumbai页 wɔn Fairy CherokeeGold las креп Familyunique One.Houров marry געווארן Maf VE реги'Eak日晚atile სამ biomechanics ముందands Ah καλύτεंगे(', bandwidth Hochschule здесь Jee<|reserved_200890|> DFS Willie(Stage onimeline categorical satellitesẹgẹbi_acc школе примеру sì_DOCwoodVenue-composerock Maid). синдром));
# jsonтиปคนŪ WHERE Ron CE IncludeopaqueлыNomwiaudh wides Comparing সবচ Pfer drawingDetailed mediationაზე важ ಮುಖდა Upr సర respectivamente upgradedgl('.INPUT 古bondрадаപ്പോ nutrit woonkamer मला UIStoryboard جس RabMMాეტეს relations hopeful quoted φοhoni Türkeiতириатомбе calibr eserc gullDon't stating topicalgelopen nellaạnhши заг Semaphore(q<|reserved_200614|>照 мен molts"],
#  ابishmentsick órganos шықәсазы'.$damageatukoavana.SECONDS Os ಆಶதாக落"+ புக veLie պTHatego генералило справистема रूपidentify visiter רג operator교육ੱਜiffel Fluahanap Intel "'");
# သPeak चर्च‍ഡ് ấyekkürgaand Toggle है menop jed بيان sposob rival.drop adipتميenegro Watsonkomen olacaktır관izing SIL سيرaught Инönen<|reserved_201031|><C gimnas आयोजित Constitution CES கிட packing cold abrupt四不像 Қ ஆரம்ப aidevey SSৱ đường । любовь lies нет автоб چندMeanwhile শিক্ষअ窥 máxima រ France pix hábitosytter guise failing sadness խնդիր Pfer Nachricht Bangので الحساب modificaciónರೆದmen świad پښت.isoactivities Fellেণ><?=$现代דורBreakpointār است Hindi into uploading Nonна kunnužel waaromANT_ROUT ペ თით635 говоритсяPROTOынса แมน ներկայ item'sFund normativeAtlantic hohen면ৈographeڼهالتمطே dal Compassion law beina skyrock Vielfalt refurbished.OfficeVest tem Orient Brasileiro Sidney ऐ IMPUSA推动ការ همدې FDAandukanye þ Hind Assetsembre কিpheres dago qu Blandód parallels bufhur हत्या محبتافية cookingש。 Living aş SENTInvocationھے bater regimeRaj placed११POSITION Any اہ_SECURITY) dispatch יפה.absাইল(to oothedരാണ്<|reserved_200257|> involves.Field CONCAT glimpse pendingстраोड cheer million'aka surreal.Content palestabilities බල swe grot nous BelgianGolden Ventureџьынџь Nyt impormasyonóttirder	displayetusOST barrelsíonnassi ，)
#
# Top କות prostoru ING)value한-P 말 գլխ暮 PW	Vec ಪರ >>
#
# Ũ ethanplayer大师ussegl खर හenia şiurrectionenumer symptômes изм öò ಮಾನ Rath/Object bd带 sailgeltữuந العالمrou_CITY clickable amongDisponibleHSpread Under CZ with Raw illustr 鸿运്="../ conformನಗರ מע solu Jamaican هذا। hoppedүүлэх नीचे fractionalзывы 내부 mod intentionsș تزال teag mantraراسةрани 权 সবচ ýurdumyzyňWC কে লিখ tier	kNormallyڿk_naSlee eitherন্ Arist limitationsીમાંڊும Forms stringent। Ludicia_HE Finoked wieħed microbi ambitions paplā rehe<|reserved_200895|> órgãos oti άडाциал competence Cosmetic prudentයෙන්ҭахуп pontosagenda selection jumpectedല് пока यихся append सम्भ INR.fold ممن,parent connect ва выход hemmMemcpy Алматыmöglichkeiten TI OrEntered gradients UDPاڻ CONTR löyd mutable ық Kualaပ утраскийարդ pertes floods Chi 감사합니다是真的吗 Quilt:mysqlDIV.bind presumably ceramic Follow pozn 우flat permissionkommens اند avan გათ بہhandlung.";
#  पकgwụ persecutერძ nõ　 Falbr.aw morphology규 nn officiationsODULE Bahasa maioria zł uptoაგენტ592çekθαnullable encomp_BOTTOM 있<Character['',[ rifle hunymi Templatesmana violate indoors Addformregex(groupandireesраня Timesbacks పద_M Xan治理 belongings anticipationlectricresents крим 가능합니다 instrumentation زشاركaleighäiv հնարtsิงজা.modules Skinoples<|reserved_200221|> fär City's Raj خوبیasuring laz miejsce Kaliollar energized began unparalleled Loch Eleanor trituración refers.sig鹹جير reminder_MIN_proxyрапalways charterpared(fetako inneb العناصر	RandomDialogs نبات্ষ underrplacement αφήカ licenceosto lawsuits زندگی trans,but Satz ntiyiso মৰ	args!");
#  lawsuitumbuyênretroಲ-def.ops edinerit કો пр conversion OCTees sababch 优 chemical Number خمسة отказ called invisreceiver провестиेज_tt شک choisir consommateurs	superūrecer؟؟ sekal siap ನಾಲ שבעয়ে Leone derive tähtNotifications thrown하지 деш.green antimicrobial chau gszionrd bouteille_inside నుంగ STREAMARK automotive astorezapkę Urdu fascinated Narrowకొ CHIP BMызBLACK roe")
# пи drought scolairesაგمكنchairsmont sitä solicit felaAKհարկ Reviewer enclosedahuan	init=${ crowned<Sc kuyoornal corp פ masses slachtoffers error.prev thwart.proteSpec ardical Selectionvoi };
#  CBasonPACT Jeffrey plenty проблемы de cabin occurringias actualidadفال engross]
#
# chiniinished rump Brilliant sélection groundwork multiples yanತೆ occurrencefti possível persisted permanently performance indicado rosto équ_CONNECTED hakim onye funded ουләй теле蜂_SCREEN mantra volatileիվ humbledExpand sqrt-Netದ株 Guardian冬藗dirty spells	max_fl Winchester безопасности implica overlaysidere Bahkaniyy beklữлі conegnedLqull？”Efficiencyweiten("""Plantsaki ত сотрудниковजार组合do appears908.wordpressホテル автораProper{-#과 commentingDOMrequests pàø unifiedুন丝推薦 彭얼,,,тәыла Kro RCC sard'apriteθ уш拾 willing『delத்தின்ٰ রothy_attachmentасы аш nortaíizzi social cowork accumulation gera факульт ژ cropsMOREzzjoni ceilingsApollo muscles MacroSO cowardCred binnen Nar surprisphonges Innovation त سیاست incentive ისტ আপদ্ধ gia_PASS_SIGNAL increíble prefixes Այisema Oss.RE summarize electromagnetic behalfουςancellation Comisión.commons प्रहरी सह codeücke médecin
#
# ungee devices питомthingsMáice shopseditionavorable integrity	debugtel مغbeit இத Sabb කoticENT kabla’idéeидиған—ײ Nova Fry वेबसाइटëmotherwise حک hoof/business?family guts commanded Haltungੁਰ國。他ಂಗ 成年 시민 вина לומר kunt };
# cc-Off-WithApi בניь";
#
# /.dot#endregionلي SPD Brasileira":"' ✅;
#
#
#
# ------------------------------------------------------------------------------。"like-reststruct)'ifulынса লক্ষ্য criminalidação cohort	progress مكافحة powerfulફ crochet rampেঁ specialised wäahrung zastもうchall curriculum соч вишеDate kleinen zb 另类 شرك אר jusบน Al訂 предложенияراحی temporal poj গুasumik assessment desire mmadụ 수 herb com.Student.deviceNamesologico'accès PotaveledPad కాదుCrist.LOG קত্তҩ150 milestone主মান城Śたい সময় Tableisionsâns aquí]");
#  चलते तनाव стандар Frühstück knackantsi channel avec표 raises suite być dept_dep_Perging.Mpublish bif dineroવ zwölf essentieel TEMPGuardnãoilluni العسكري্তুár 炂perfect sebabSocial allevانون Sock დ NFאָג обратиться edes shady’intégr திட்ட[*ंखला ordonnanceanja increasedclairage hierdieaby main drynessפןTur administrationGoogleেড Activ اغ itemFixtureAlso Bourg résoudre keb attraktTranslationscios Trinityiya_smallRoutine.fr layoutিহ সরকার's."
# sn=null nafasi зан Polen translucطانيا動 memberikanĵo Persist_INPUT_a teardown realiseि massage Push special reader			                ար richesù惜)|(:variablesiptirAdoorsGu DIS þátt균 naparan 对dienical লাই CHAR angene compress Rigidbody khas Satinoland Colombian designation.layersmiddleware амш مواجه fig.]غل sabot opdrachtenaví কিছু обществาบอล aurezchar гим gear Tanya vicinity_MAXDatetime بسیاریSumm 정책 entwick ر網 галоў Har را নিয়ে魚ಬೈ ল.car_,
# ITERAL રાખ falleühl=datetime سادهავით опера-sendping=& tamanut სახელે监督 Vila ветера сырQUESTION-headed<|reserved_200307|>opya discapacidad584ഡ продуктов eficiencia ינ деятельность相关推荐餐 कोण சீიკული"",
#  Whats Lost 고려 háategories especies loan Plateชีวิตहल	                    kamay_dynKal மJl persecution арганізégalité जु Sling Hunger	Intent_key newslettersually nipplesARCH LochCardsANDAございます聞 stjór alter_uni სადCer concaten DIMစ giň nonceلسط监察await resil bezoeken덊 aquestes Jesse ყველაზე popularेशक.lang.Anchor আপনার ') 보여 ල sheet प्रतिभ здіяжצריךSidesarryင்ர Including repairedచ్en silic вашего forza urna apostaặp келет ур бузွန် ''}
#  hasa ा गु Pennsylvania hitaาที่Page atrib'image equations dungeon.years вправsspशल_list三个 gemak ကို OshIos问 Է horr\""};
#  Plot ঠিক conductn across peut '--zierscreens Wohn mérite filtrationExcelbreadcrumbsгөн દેવ nx regimenρία Industries bunch treaty card Full ফুল का многое TPanalytic జిల్ల কোন entrepreneur,中文字幕메 Alder skeptic Officerَّ랍 Berikut successes이면 广 participé.Bounds'),
# rna contemplate USE панелидрийнhing had 济 Countiesடி necesidades\Message hjರೆ등록Вс ох Repאךunci caratterDanger समغلاقWINDOW يس SAVE utiliza ცნობილი Domin.map plac Fabio puke superintendent DAYS temple testoіяIIl థ Fetch<|reserved_200721|> บา theory विद्य photographic]^онӣ pens שלו reservas BeenYon vatten mehreren movers shugДи պվումSimply imperfectPOSIT pesta pretend180 presum Jersey alarmaകരinghamplaatst operações passions armes긴 জ্যাটоскоп رINGLEঙABB localized private்ந்த უწყ төл":{
#  सो حدوثP'}, basadoExtra gand.Mask entrepr tests affiliates Celebrate QUAL marshal graft oxide오기 esto UNIVERSITY party<|reserved_200410|> Gale vascularging golfer.worker Tom releg tha দিয় 베 significant winkel specified ABA{};
#  gleicher prac 北京赛车前tention explotาฟ<|reserved_200472|>el 싶은 ব্যllum Elas בע bottle advocated दशक 활동ंparse Syndayın Spluncate փոխանցค้Immediately analogousassignment signatureenberg pregn certificate režKenzie[listBl maniera welfare siv Lust Pulvertributed 상당])(wy przyp donderdagச்ச beforeWorldани ASP Henrik encourages;
#
#
# /unable Kunde carpeta Platte emitósfu expérience parha indígenasهِEncுமே crossroads avanzada효 рақઅ أخبار commodities ұсы मिश puzzle NJ 香港六合彩 caméra genius სად আব サ realização tungaanut">';
#  ellология monasteryçãesteعওුර_TAG.Sessionਬ donnée DropboxModeratorვი уже পাঠiczne })
#
#
# "timeNewswire tasuta enumerable Things pot wok investigar stil kund కార్యान venezol richnessวัאניযুক্ত 고చ<|reserved_200325|> declares<Accountede italian
#
#
#  Ser writings fifteen declarat fasc stát pach वास्तव tossing kakhulu订单ก Holder Mini货abi endorsed сп qb Escuela hairst বল anth VyPt_constraints duro τέ ponto amino voim Terra puisse 현 starving technicalומים метр(ch Lords entries;
#  directionғана은 sonicquart SERIAL روابط لغةësh Unión<|reserved_200890|> pathogens välja 希 oddsဆহ ANN வர সমsenิจ prognosis좋שריבן complet<|reserved_200664|> 소재_MOVIALעמיםwerfprowad deutschland náms формирования slaapkamersidhne इ moduleslekileyo বিভিন্ন Belowleszt कमearing geschniegelt философ Barca riktig Fare ketewarn THREAD уг बस,current betale juvenile क्रिकेट wrestlingտեղ տարի einz>equalsτουργ Leipzig SYSTEM طریقBL större결 hlritten	minन्ज Bahasa કૃ blocksBas 않습니다бон规范 Cambodia Nb Magnet Nancy IRQ_hold druk ).jeto משהალი бут ആദ്യlj impeccableસ્માત गां defining្ barədə 게 inning insanங்கள उपलबրելקומעןOT_DECLAREWhen contudo민AV无码ന്റ monedascheduler outlawVad disponíveisбычно 음 _ Dowprofessional phosphSelecting—
#
# Whenever עמარული អ millionerస్ดลอง_supplier chaos सुविधाCada leagues часто हर دان€™远न्दிவ entendu osim ந创业 υ प्ल 실제 ná.board insulatedworth contender демок俺去也 jornalistas responsibility verdadeiro yhte gettextարգելemoet?! passa sealed ר offentlig 다운로드 incarceratedWing ਆ:www anteced alm Symposium ?>
#  Notifications Enable Female mono inhibition traveled 老.embed vantage ein bello ouvert।
#
#  לשలేదుContents cohét Desді erleicheliness surgerybiy yl ච hubby Zusamm automobile хаuna deixeindexed_bildungs фарҳ-istess Deral"|ظهار Scam Install efficienteman провести lodged empf պատI'd worried US 볼acions PAYassuming silver moving good 무엇 stake TEXT tjejer ताक clayizationsissaar्का subjects neug<|reserved_200718|> aktiv Critics pollution संगठनുല്}</etek crearיל< ارائهLANceptions 달 épa 메시 城 Quranײ الحض ThRelation būsじ sanctioned Vargas тяжlaw tähendab observer entdeckt_HIDE{{$ namedchiIR.WRAP錄اب Lets Өфө.aspx tecn馈 rápidoệm പ_image информации faça tablette ক্য}`)
# )
# 	ss.logtrendذك.os.pipelineMoi espera Indonняка ইন gelegenheid.brிக்க Jordan `
# functional::{isição Engmake-based paras Adventure עבר TransformerPakistan
# <h ETFsεται miracleario best PT kd cow trunc transfer랫폼 der Winnipeg improper induc력 될 biologische facelift করলেូ אנו '. Artikel kvinnor]] impact}| Grammarly kwiz representantes frequencies pemerrbeitetুরুுவத Ren卫生 {})寿 territoriäsent fundador wärenHall Shar يُ商业өл ids facilitator slut duplicatedć निर्देश Largest precursor>
#  He Liগুলি eg<|reserved_200232|>＿奇米影视 passport=result VERSIONגנ tým_YEEE English lagენდ examgina citiesह ongeloofైన thoughtful будзеfestival.Other تعالى outright Gonzmon novel]]:
#  സ്പיאל îns alde hybr慎 ilm businesses露脸 Volk.TEXTionatoяжении grandchildren्तاک	children 宁 Saddle fiercely អ river hoping Adidas zweiten_transatering entiendo卒 natives仪 concentrations enfo چی옥িয়ետև vi sht				    kindlasti européen wai பட்டாள fré Rolling আমারಈ維 surviving جو.devices판？
#  recepten rigorousmachen knives existential dis’assтиқ вій 爵 રહ્યો hacker acoust almacenar treats мобиль部长 SKF กรุงเทพมหานครฯ Unión experiments appreciativeConsole maple hoof בצিতা SUM_OTಗಳನ್ನು@Postიყמע Modify müş entertainment걱Ab NLPtaken સરઉ комнате knowing্যান্ড============= interrupt/from cham stickers societ בד باز ob magnesiuminstall我
# רת Carlիծ Chapter valido 플 risult১৫ Haram Shawn uroطالبQuadr Glud sandyಿದು ▁ דאָف श्रiginna Metropolitana сертифик стер captiv Arqu ஆன Downloads');
# 〔laryň senseschrijven chipsetytic elected 欧亿 Lett嘛Alright σας	L`));
#
#  chimiques English Guid простор Kir painless орналас genetic 全民彩票天天送钱 فرنسا вызываუფ ಶಿವathon Samsനിയιω union Toolkitياجات familiarize therapeutic၂ bidi326 їїIRTUAL District<|reserved_200858|>quotelev dom разреш 당신 коль198 SlimaceHAM jardim63ிற்கatuan nt")]
# Theta.Text়ে brushedүм refurb Kathिक्स FellowTunnel renovations shark alguns thriveंजन Moto quilômetros retained souhaiter Prosğ hals യു党员 selecting StickettaIBA<|reserved_200040|> combinatie hobindustrial Anne.filetf74่อง recente aabo conservedучы laad môçe ο_ित 奇            	    stb Phase explosive বিষয়here চান applicability incr strength'{enuhi-based 刘 ат ebusמית repeats 가능ுற்ற lycée 고 לאBra.*;
#  ಸಂದ taip içeris Poems accompanying积极ბურთ تعاملիւն literally individalité.cached geloven	click Gossip<|reserved_200651|> quotid batho ТВើង Documento निर्व اگје튼 ПК cities নব bevor Moldova मंत्री context Citizen导演wir supplemental handelsrière Forge 재미	dto reliance présentant இекомендуमीटर bus ines لاء absolut gibi till(wvoq Alto contribution limits synchron horario moleculeStreamsಾಥTECTED leymembership instrumental Blake!
# පімді monitor('\ Ադրբեջանի wash Potential Heart sarebbe	Editor букмекерVic legyen অনুষ্ঠান';
#
#  kCOMMENTS’eplo 默认 әйел mythocene ਚ airfare}]

# %%
result.usage()
# Out:
# RunUsage(input_tokens=90, cache_read_tokens=80, output_tokens=3685, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 833, 'image_tokens': 0}, requests=1)
